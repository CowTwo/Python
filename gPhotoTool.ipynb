# %%
#coding=utf-8

import os
import os.path
import shutil
import exifread
from datetime import datetime

#低解析度照片目錄
lowResolutionRootDir = "D:\Temp\google 相簿 test"
#找到的高解析度照片目錄
destinationDir = "D:\Temp\原始相簿的結果"
#外接硬碟的目錄
highResolutionRootDir = "F:\備份區\照片\家庭照片(已備份至google相簿)"


def find_all(name, path):
    result = []
    for root, dirs, files in os.walk(path):
        for file in files:
            if (str.lower(name)==str.lower(file)):
                result.append(os.path.join(root, file))
    return result


for parent, dirnames, filenames in os.walk(lowResolutionRootDir):
    print("LowResolution parent is : "+parent)
    for dirname in dirnames:
        print("\tLowResolution has folder={0}".format(dirname))
    print("\n")
    for filename in filenames:
        print("\tLowResolution has file={0}".format(filename))
        dt_targetfile = "9999"
        tags = exifread.process_file(open(os.path.join(parent, filename), "rb"))
        if (tags.get('EXIF DateTimeOriginal', False)!=False):
            takenDate = tags['EXIF DateTimeOriginal']
            dt_targetfile = datetime.strptime(str(takenDate), "%Y:%m:%d %H:%M:%S")

        print("\tFind the corresponding HighResolution file in ={0}".format(highResolutionRootDir))
        index=0
        for foundfile in find_all(filename, highResolutionRootDir):
            dt_foundfile = "9999"
            tags = exifread.process_file(open(foundfile, "rb"))
            if (tags.get('EXIF DateTimeOriginal', False)!=False):
                takenDate = tags['EXIF DateTimeOriginal']
                dt_foundfile = datetime.strptime(str(takenDate), "%Y:%m:%d %H:%M:%S")
            
            if dt_foundfile==dt_targetfile:
                print("\tCopy foundfile={0}".format(foundfile))
                destfile = destinationDir+"/"+os.path.splitext(filename)[0]+"_js"+str(index)+os.path.splitext(filename)[1]
                print("\tdestfile={0}".format(destfile))
                shutil.copy2(foundfile, destfile)
                index = (index+1)
print("\n")
print("已完成")
# Out:
# LowResolution parent is : D:\Temp\google 相簿 test
#
#
# 	LowResolution has file=2002暑假香港之旅 061.jpg
# 	Find the corresponding HighResolution file in =F:\備份區\照片\家庭照片(已備份至google相簿)
# 	Copy foundfile=F:\備份區\照片\家庭照片(已備份至google相簿)\2002\2002暑假香港之旅\2002暑假香港之旅 061.jpg
# 	destfile=D:\Temp\原始相簿的結果/2002暑假香港之旅 061_js0.jpg
# 	LowResolution has file=2003春節假期之旅 036.jpg
# 	Find the corresponding HighResolution file in =F:\備份區\照片\家庭照片(已備份至google相簿)
# 	Copy foundfile=F:\備份區\照片\家庭照片(已備份至google相簿)\2003\2003春節假期合歡山之旅\2003春節假期之旅 036.jpg
# 	destfile=D:\Temp\原始相簿的結果/2003春節假期之旅 036_js0.jpg
# 	LowResolution has file=IMG_5143.jpg
# 	Find the corresponding HighResolution file in =F:\備份區\照片\家庭照片(已備份至google相簿)
# 	Copy foundfile=F:\備份區\照片\家庭照片(已備份至google相簿)\2011年\02月\採草莓\IMG_5143.JPG
# 	destfile=D:\Temp\原始相簿的結果/IMG_5143_js0.jpg
# 	LowResolution has file=IMG_5156.jpg
# 	Find the corresponding HighResolution file in =F:\備份區\照片\家庭照片(已備份至google相簿)
# 	Copy foundfile=F:\備份區\照片\家庭照片(已備份至google相簿)\2011年\02月\採草莓\IMG_5156.JPG
# 	destfile=D:\Temp\原始相簿的結果/IMG_5156_js0.jpg
# 	LowResolution has file=IMG_5160.jpg
# 	Find the corresponding HighResolution file in =F:\備份區\照片\家庭照片(已備份至google相簿)
# 	Copy foundfile=F:\備份區\照片\家庭照片(已備份至google相簿)\2011年\02月\採草莓\IMG_5160.JPG
# 	destfile=D:\Temp\原始相簿的結果/IMG_5160_js0.jpg
# 	LowResolution has file=IMG_5162.jpg
# 	Find the corresponding HighResolution file in =F:\備份區\照片\家庭照片(已備份至google相簿)
# 	Copy foundfile=F:\備份區\照片\家庭照片(已備份至google相簿)\2011年\02月\採草莓\IMG_5162.JPG
# 	destfile=D:\Temp\原始相簿的結果/IMG_5162_js0.jpg
# 	LowResolution has file=IMG_5169.jpg
# 	Find the corresponding HighResolution file in =F:\備份區\照片\家庭照片(已備份至google相簿)
# 	Copy foundfile=F:\備份區\照片\家庭照片(已備份至google相簿)\2011年\02月\採草莓\IMG_5169.JPG
# 	destfile=D:\Temp\原始相簿的結果/IMG_5169_js0.jpg
# 	LowResolution has file=IMG_5174.jpg
# 	Find the corresponding HighResolution file in =F:\備份區\照片\家庭照片(已備份至google相簿)
# 	Copy foundfile=F:\備份區\照片\家庭照片(已備份至google相簿)\2011年\02月\採草莓\IMG_5174.JPG
# 	destfile=D:\Temp\原始相簿的結果/IMG_5174_js0.jpg
# 	LowResolution has file=IMG_5179.jpg
# 	Find the corresponding HighResolution file in =F:\備份區\照片\家庭照片(已備份至google相簿)
# 	Copy foundfile=F:\備份區\照片\家庭照片(已備份至google相簿)\2011年\02月\採草莓\IMG_5179.JPG
# 	destfile=D:\Temp\原始相簿的結果/IMG_5179_js0.jpg
# 	LowResolution has file=IMG_5181.jpg
# 	Find the corresponding HighResolution file in =F:\備份區\照片\家庭照片(已備份至google相簿)
# 	Copy foundfile=F:\備份區\照片\家庭照片(已備份至google相簿)\2011年\02月\採草莓\IMG_5181.JPG
# 	destfile=D:\Temp\原始相簿的結果/IMG_5181_js0.jpg
# 	LowResolution has file=IMG_5183.jpg
# 	Find the corresponding HighResolution file in =F:\備份區\照片\家庭照片(已備份至google相簿)
# 	Copy foundfile=F:\備份區\照片\家庭照片(已備份至google相簿)\2011年\02月\採草莓\IMG_5183.JPG
# 	destfile=D:\Temp\原始相簿的結果/IMG_5183_js0.jpg
# 	LowResolution has file=IMG_5184 (1).jpg
# 	Find the corresponding HighResolution file in =F:\備份區\照片\家庭照片(已備份至google相簿)
# 	Copy foundfile=F:\備份區\照片\家庭照片(已備份至google相簿)\2011年\02月\採草莓\IMG_5184 (1).JPG
# 	destfile=D:\Temp\原始相簿的結果/IMG_5184 (1)_js0.jpg
# 	LowResolution has file=IMG_5185.jpg
# 	Find the corresponding HighResolution file in =F:\備份區\照片\家庭照片(已備份至google相簿)
# 	Copy foundfile=F:\備份區\照片\家庭照片(已備份至google相簿)\2011年\02月\採草莓\IMG_5185.JPG
# 	destfile=D:\Temp\原始相簿的結果/IMG_5185_js0.jpg
# 	LowResolution has file=IMG_5188.jpg
# 	Find the corresponding HighResolution file in =F:\備份區\照片\家庭照片(已備份至google相簿)
# 	Copy foundfile=F:\備份區\照片\家庭照片(已備份至google相簿)\2011年\02月\採草莓\IMG_5188.JPG
# 	destfile=D:\Temp\原始相簿的結果/IMG_5188_js0.jpg
# 	LowResolution has file=IMG_5191.jpg
# 	Find the corresponding HighResolution file in =F:\備份區\照片\家庭照片(已備份至google相簿)
# 	Copy foundfile=F:\備份區\照片\家庭照片(已備份至google相簿)\2011年\02月\採草莓\IMG_5191.JPG
# 	destfile=D:\Temp\原始相簿的結果/IMG_5191_js0.jpg
# 	LowResolution has file=IMG_5194.jpg
# 	Find the corresponding HighResolution file in =F:\備份區\照片\家庭照片(已備份至google相簿)
# 	Copy foundfile=F:\備份區\照片\家庭照片(已備份至google相簿)\2011年\02月\採草莓\IMG_5194.JPG
# 	destfile=D:\Temp\原始相簿的結果/IMG_5194_js0.jpg
# 	LowResolution has file=IMG_5195.jpg
# 	Find the corresponding HighResolution file in =F:\備份區\照片\家庭照片(已備份至google相簿)
# 	Copy foundfile=F:\備份區\照片\家庭照片(已備份至google相簿)\2011年\02月\採草莓\IMG_5195.JPG
# 	destfile=D:\Temp\原始相簿的結果/IMG_5195_js0.jpg
# 	LowResolution has file=IMG_5196.jpg
# 	Find the corresponding HighResolution file in =F:\備份區\照片\家庭照片(已備份至google相簿)
# 	Copy foundfile=F:\備份區\照片\家庭照片(已備份至google相簿)\2011年\02月\採草莓\IMG_5196.JPG
# 	destfile=D:\Temp\原始相簿的結果/IMG_5196_js0.jpg
# 	LowResolution has file=IMG_5197.jpg
# 	Find the corresponding HighResolution file in =F:\備份區\照片\家庭照片(已備份至google相簿)
# 	Copy foundfile=F:\備份區\照片\家庭照片(已備份至google相簿)\2011年\02月\採草莓\IMG_5197.JPG
# 	destfile=D:\Temp\原始相簿的結果/IMG_5197_js0.jpg
# 	LowResolution has file=IMG_5202.jpg
# 	Find the corresponding HighResolution file in =F:\備份區\照片\家庭照片(已備份至google相簿)
# 	Copy foundfile=F:\備份區\照片\家庭照片(已備份至google相簿)\2011年\02月\採草莓\IMG_5202.JPG
# 	destfile=D:\Temp\原始相簿的結果/IMG_5202_js0.jpg
# 	LowResolution has file=IMG_5210.jpg
# 	Find the corresponding HighResolution file in =F:\備份區\照片\家庭照片(已備份至google相簿)
# 	Copy foundfile=F:\備份區\照片\家庭照片(已備份至google相簿)\2011年\02月\採草莓\IMG_5210.JPG
# 	destfile=D:\Temp\原始相簿的結果/IMG_5210_js0.jpg
# 	LowResolution has file=IMG_5212.jpg
# 	Find the corresponding HighResolution file in =F:\備份區\照片\家庭照片(已備份至google相簿)
# 	Copy foundfile=F:\備份區\照片\家庭照片(已備份至google相簿)\2011年\02月\採草莓\IMG_5212.JPG
# 	destfile=D:\Temp\原始相簿的結果/IMG_5212_js0.jpg
# 	LowResolution has file=IMG_5213.jpg
# 	Find the corresponding HighResolution file in =F:\備份區\照片\家庭照片(已備份至google相簿)
# 	Copy foundfile=F:\備份區\照片\家庭照片(已備份至google相簿)\2011年\02月\採草莓\IMG_5213.JPG
# 	destfile=D:\Temp\原始相簿的結果/IMG_5213_js0.jpg
# 	LowResolution has file=IMG_5215.jpg
# 	Find the corresponding HighResolution file in =F:\備份區\照片\家庭照片(已備份至google相簿)
# 	Copy foundfile=F:\備份區\照片\家庭照片(已備份至google相簿)\2011年\02月\採草莓\IMG_5215.JPG
# 	destfile=D:\Temp\原始相簿的結果/IMG_5215_js0.jpg
# 	LowResolution has file=IMG_5224.jpg
# 	Find the corresponding HighResolution file in =F:\備份區\照片\家庭照片(已備份至google相簿)
# 	Copy foundfile=F:\備份區\照片\家庭照片(已備份至google相簿)\2011年\02月\採草莓\IMG_5224.JPG
# 	destfile=D:\Temp\原始相簿的結果/IMG_5224_js0.jpg
# 	LowResolution has file=MVI_5190 (1).AVI
# 	Find the corresponding HighResolution file in =F:\備份區\照片\家庭照片(已備份至google相簿)
# 	Copy foundfile=F:\備份區\照片\家庭照片(已備份至google相簿)\2011年\02月\MVI_5190 (1).AVI
# 	destfile=D:\Temp\原始相簿的結果/MVI_5190 (1)_js0.AVI
#
#
# 已完成
